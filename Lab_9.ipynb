# %% [markdown]
# <a href="https://colab.research.google.com/github/241b194-tech/APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %% [markdown]
# #Modify program for user input graph using dictionary

# %%
n=int(input("Enter number of nodes: "))
g=dict()
for i in range(n):
  N=input("Enter Node: ")
  a=int(input("Enter number of adjacent nodes: "))
  ad=dict()
  for _ in range(a):
    v=input("Enter Adjacent Node: ")
    w=int(input("Enter weight of edge: "))
    ad[v]=w
  g[N]=ad
# Out:
# Enter number of nodes: 5
# Enter Node: a
# Enter number of adjacent nodes: 2
# Enter Adjacent Node: b
# Enter weight of edge: 10
# Enter Adjacent Node: c
# Enter weight of edge: 3
# Enter Node: b
# Enter number of adjacent nodes: 2
# Enter Adjacent Node: c
# Enter weight of edge: 2
# Enter Adjacent Node: d
# Enter weight of edge: 1
# Enter Node: c
# Enter number of adjacent nodes: 3
# Enter Adjacent Node: b
# Enter weight of edge: 4
# Enter Adjacent Node: d
# Enter weight of edge: 8
# Enter Adjacent Node: e
# Enter weight of edge: 2
# Enter Node: d
# Enter number of adjacent nodes: 1
# Enter Adjacent Node: e
# Enter weight of edge: 7
# Enter Node: e
# Enter number of adjacent nodes: 1
# Enter Adjacent Node: d
# Enter weight of edge: 9

# %% [markdown]
# #Display shortest path with total distance

# %%
result = dijkstra(g, 'a')
del result['a']
print(f"Shortest path with total distance for node:")
for i in result:
  print(f"a -> {i} = {result[i]}")
# Out:
# Shortest path with total distance for node:
# a -> b = 7
# a -> c = 3
# a -> d = 8
# a -> e = 5

# %% [markdown]
# #Add two more nodes in graph

# %%
for i in range(2):
  N=input("Enter Node: ")
  a=int(input("Enter number of adjacent nodes: "))
  ad=dict()
  for _ in range(a):
    v=input("Enter Adjacent Node: ")
    w=int(input("Enter weight of edge: "))
    ad[v]=w
  g[N]=ad
# Out:
# Enter Node: d
# Enter number of adjacent nodes: 2
# Enter Adjacent Node: b
# Enter weight of edge: 3
# Enter Adjacent Node: e
# Enter weight of edge: b
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8045/184486728.py in <cell line: 0>()
#       5   for _ in range(a):
#       6     v=input("Enter Adjacent Node: ")
# ----> 7     w=int(input("Enter weight of edge: "))
#       8     ad[v]=w
#       9   g[N]=ad
#
# ValueError: invalid literal for int() with base 10: 'b'

# %% [markdown]
# #Test algorithm with different source nodes

# %%
for j in 'a':
  result = dijkstra(g,j)
  del result[j]
  print(f"Shortest path with total distance for node {j}:")
  for i in result:
    print(f"{j} -> {i} = {result[i]}")
